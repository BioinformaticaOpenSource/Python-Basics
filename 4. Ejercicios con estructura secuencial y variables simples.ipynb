# %% [markdown]
# # 4.0 Ejercicios con estructura secuencial y variables simples
#
# En esta sección realizaremos unos programas usando el paradigma de programación estructurada, pero solo usaremos estructura secuencial y variables simples.
#
# ***NOTA:***
#
# Cada programa debe tener:
#
#     Entrada:
#         Constantes
#         Variables
#         Etiquetas
#
#     Proceso:
#         Operaciones
#
#     Salida:
#         Impresiones en consola usandpo la funcion "print()" con forma de un reporte donde muestren los datos
#         de entrada (Variables) y resultados (el formato de presentacion es como ustedes quieran).
#
#         ejemplo:
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## 4.1 Ejercicios
#
# ### Ejercicio 1
#
# ***Problema***
#
# Crear un programa que calcule el área de un triangulo:
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Ejercicio 2
#
# ***Problema***
#
# Crear un programa que calcule la hipotenusa de un triangulo:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Ejercicio 3
#
# ***Problema***
#
# Crear un programa que calcule la distancia entre dos puntos en un plano cartesiano:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Ejercicio 4
#
# ***Problema***
#
# Crear un programa que calcule la pendiente entre dos puntos:
#
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Ejercicio 5
#
# ***Problema***
#
# Crear un programa que calcule el area de un rectangulo:
#
#
# ![image.png](attachment:image.png)
